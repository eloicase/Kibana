# %% [markdown]
# ## S15 T01: Visualització interactiva amb ElasticSearch Stack
# ### Comencem a familiaritzar-nos la visualització interactiva de gràfics mitjançant Kibana.
# #### Eloi Canals

# %%
from IPython.display import Image
from IPython.display import IFrame, display

# %% [markdown]
# Nivell 1 - Exercici 1
# Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %%
# Carregarem un dataset de logs propi per començar a explorar i fer algunes grafiques
# Logs de accessos de servidor Apache

# %%
Image(filename='img/importdata.jpg')

# %%
# Primeres grafiques exploratories
Image(filename='img/Exploring1.jpg')

# %%
# Explorant les ips
Image(filename='img/Exploring2.jpg')

# %%
# Explorant els requests
Image(filename='img/Exploring3.jpg')

# %% [markdown]
# Nivell 2 - Exercici 1
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %%
# Dashboard
Image(filename='img/MyDashboard.jpg')

# %% [markdown]
# Nivell 3 - Exercici 1
# Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %%
# Mostra dels diferents grafics de Kibana en un Dashboard
Image(filename='img/All-the-graphs-dash.jpg')
